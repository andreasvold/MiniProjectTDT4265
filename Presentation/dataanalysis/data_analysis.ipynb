# %% [markdown]
# Image Characteristics NAPLab Natural Image Pole dataset

# %%
import sys
import importlib

# Add project directory to the path
sys.path.append("/Users/andre/projects/MiniProjectTDT4265")

# Import modules **after** modifying sys.path
from data_analysis import bounding_box_analysis
from data_analysis import image_size_check
from data_analysis import plot_aspect_ratios

# %% [markdown]
# Image size check of training and validation images

# %%
print("\n Training data \n")
image_size_check.check_image_sizes("/Users/andre/projects/MiniProjectTDT4265/datasets/rgb/images/train")
print("\n Validation data \n")
image_size_check.check_image_sizes("/Users/andre/projects/MiniProjectTDT4265/datasets/rgb/images/valid")
# Out:
#  Training data
#
# Min size: (1920, 1208)
# Max size: (1920, 1208)
# Average size: (1920.0, 1208.0)
#
#  Validation data
#
# Min size: (1920, 1208)
# Max size: (1920, 1208)
# Average size: (1920.0, 1208.0)

# %% [markdown]
# Aspect ratio histograms of training and validation images

# %%
plot_aspect_ratios.calculate_aspect_ratios(
    "/Users/andre/projects/MiniProjectTDT4265/datasets/rgb/images/train",
    "/Users/andre/projects/MiniProjectTDT4265/datasets/rgb/images/valid"
)

# %% [markdown]
# Bounding Box analysis

# %%
print("\n Training data: \n")

bounding_box_analysis.calculate_box_statistics("/Users/andre/projects/MiniProjectTDT4265/datasets/rgb/images/train", "/Users/andre/projects/MiniProjectTDT4265/datasets/rgb/labels/train", False)

print("\n Validation data: \n")
# for validation images
bounding_box_analysis.calculate_box_statistics("/Users/andre/projects/MiniProjectTDT4265/datasets/rgb/images/valid", "/Users/andre/projects/MiniProjectTDT4265/datasets/rgb/labels/valid", False)
# Out:
#  Training data:
#
# Average Bounding Box Area: 3577.1862652939494
# Average Objects per Image: 1.2173913043478262
# Average Overlap (IoU > 0.5): 0.0
#
#  Validation data:
#
# Average Bounding Box Area: 2989.151133773343
# Average Objects per Image: 1.2282608695652173
# Average Overlap (IoU > 0.5): 0.0

# %% [markdown]
# Image Characteristics TTPLA

# %% [markdown]
# Image size check of training and validation images

# %%
print("\n Training data \n")
image_size_check.check_image_sizes("/Users/andre/projects/MiniProjectTDT4265/datasets/TTPLA_YOLO/images/train")
print("\n Validation data \n")
image_size_check.check_image_sizes("/Users/andre/projects/MiniProjectTDT4265/datasets/TTPLA_YOLO/images/valid")
# Out:
#  Training data
#
# Min size: (3840, 2160)
# Max size: (3840, 2160)
# Average size: (3840.0, 2160.0)
#
#  Validation data
#
# Min size: (3840, 2160)
# Max size: (3840, 2160)
# Average size: (3840.0, 2160.0)

# %% [markdown]
# Aspect ratio histograms of training and validation images

# %%
plot_aspect_ratios.calculate_aspect_ratios(
    "/Users/andre/projects/MiniProjectTDT4265/datasets/TTPLA_YOLO/images/train",
    "/Users/andre/projects/MiniProjectTDT4265/datasets/TTPLA_YOLO/images/valid"
)

# %% [markdown]
# Bounding Box analysis

# %%
print("\n Training data: \n")

bounding_box_analysis.calculate_box_statistics("/Users/andre/projects/MiniProjectTDT4265/datasets/TTPLA_YOLO/images/train", "/Users/andre/projects/MiniProjectTDT4265/datasets/TTPLA_YOLO/labels/train",True)

print("\n Validation data: \n")
# for validation images
bounding_box_analysis.calculate_box_statistics("/Users/andre/projects/MiniProjectTDT4265/datasets/TTPLA_YOLO/images/valid", "/Users/andre/projects/MiniProjectTDT4265/datasets/TTPLA_YOLO/labels/valid", True)
# Out:
#  Training data:
#
# No bounding boxes in 19_00656.txt
# No bounding boxes in 63_01091.txt
# No bounding boxes in 63_01256.txt
# No bounding boxes in 63_01291.txt
# No bounding boxes in 63_01901.txt
# No bounding boxes in 63_01946.txt
# Average Bounding Box Area: 831418.0514495685
# Average Objects per Image: 8.100111234705228
# Average Overlap (IoU > 0.5): 2.6062291434927696
#
#  Validation data:
#
# No bounding boxes in 63_01871.txt
# No bounding boxes in 64_00036.txt
# Average Bounding Box Area: 896652.6654063521
# Average Objects per Image: 7.775700934579439
# Average Overlap (IoU > 0.5): 3.0093457943925235
